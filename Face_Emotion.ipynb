# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika441/CV/blob/main/Face_Emotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
img = cv2.imread('face.jpg')
plt.imshow(img[:, :, : : -1])
plt.show()
result = DeepFace.analyze(img,
actions = ['emotion'])
print(result)
# Out:
# 24-07-19 05:20:18 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 20.4MB/s]
# [{'emotion': {'angry': 0.000430252021033084, 'disgust': 7.725146744519407e-07, 'fear': 0.00023138791220844723, 'happy': 99.66356158256531, 'sad': 0.00010503033536224393, 'surprise': 0.018010425264947116, 'neutral': 0.31766120810061693}, 'dominant_emotion': 'happy', 'region': {'x': 78, 'y': 34, 'w': 81, 'h': 81, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.9}]

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 10.7 MB/s eta 0:00:00
# ...

# %%
# !pip install decode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.4/306.4 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.2/210.2 kB 5.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 16.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=481e2cd0a68e5a01844d15fec7aee2da9502cb6e90763e5852559bada5ed97ff
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# ...
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=aa5dfbb0579eaca3d2f7d07d0923d1cda7a37e64f4cdffeeb734c6a151587565
#   Stored in directory: /root/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built fire asciitree
# ...
